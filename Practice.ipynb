# %%
import pandas as pd

# %%
df = pd.read_csv('russia_losses_equipment.csv')

# %%
df.head()
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 0  2022-02-25    2        10           7    80  516               49    4
# 1  2022-02-26    3        27          26   146  706               49    4
# 2  2022-02-27    4        27          26   150  706               50    4
# 3  2022-02-28    5        29          29   150  816               74   21
# 4  2022-03-01    6        29          29   198  846               77   24
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0            100         60      0           2                      0
# 1            130         60      2           2                      0
# 2            130         60      2           2                      0
# 3            291         60      3           2                      5
# 4            305         60      3           2                      7
#
#    special equipment  mobile SRBM system
# 0                NaN                 NaN
# ...

# %%
df.tail()
# Out:
#           date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
# 36  2022-04-02   38       143         134   631  1776              317  100
# 37  2022-04-03   39       143         134   644  1830              325  105
# 38  2022-04-04   40       147         134   647  1844              330  107
# 39  2022-04-05   41       150         134   676  1858              332  107
# 40  2022-04-06   42       150         135   684  1861              332  107
#
#     military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 36           1236         76     87           7                     54
# 37           1249         76     89           7                     54
# 38           1273         76     91           7                     54
# 39           1322         76     94           7                     55
# 40           1324         76     96           7                     55
#
#     special equipment  mobile SRBM system
# ...

# %%
len(df)
# Out:
# 41

# %%
df.describe()
# Out:
#              day    aircraft  helicopter        tank          APC  \
# count  41.000000   41.000000   41.000000   41.000000    41.000000
# mean   22.000000   83.926829   92.756098  425.146341  1335.292683
# std    11.979149   42.768791   40.527633  170.695718   380.066523
# min     2.000000   10.000000    7.000000   80.000000   516.000000
# 25%    12.000000   46.000000   68.000000  290.000000   999.000000
# 50%    22.000000   86.000000  108.000000  444.000000  1435.000000
# 75%    32.000000  121.000000  127.000000  582.000000  1664.000000
# max    42.000000  150.000000  135.000000  684.000000  1861.000000
#
#        field artillery         MRL  military auto  fuel tank      drone  \
# count        41.000000   41.000000      41.000000  41.000000  41.000000
# mean        197.609756   67.756098     780.853659  65.414634  32.268293
# std          96.905593   28.721752     378.553666   6.978451  33.923461
# min          49.000000    4.000000     100.000000  60.000000   0.000000
# ...

# %%
df.isnull() # if you get true means it is improper data set and you get false it is proper data
# Out:
#      date    day  aircraft  helicopter   tank    APC  field artillery    MRL  \
# 0   False  False     False       False  False  False            False  False
# 1   False  False     False       False  False  False            False  False
# 2   False  False     False       False  False  False            False  False
# 3   False  False     False       False  False  False            False  False
# 4   False  False     False       False  False  False            False  False
# 5   False  False     False       False  False  False            False  False
# 6   False  False     False       False  False  False            False  False
# 7   False  False     False       False  False  False            False  False
# 8   False  False     False       False  False  False            False  False
# 9   False  False     False       False  False  False            False  False
# 10  False  False     False       False  False  False            False  False
# ...

# %%
df.isna().sum() # this meaning is it is display the number of missing values in column or row if it is return 0 menas there is no missing values
# Out:
# date                      0
# day                       0
# aircraft                  0
# helicopter                0
# tank                      0
# APC                       0
# field artillery           0
# MRL                       0
# military auto             0
# fuel tank                 0
# drone                     0
# naval ship                0
# anti-aircraft warfare     0
# special equipment        19
# mobile SRBM system       29
# dtype: int64

# %%
df.fillna({'special equipment':0, 'mobile SRBM system':1}, inplace=True)

# %%
df.head()
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 0  2022-02-25    2        10           7    80  516               49    4
# 1  2022-02-26    3        27          26   146  706               49    4
# 2  2022-02-27    4        27          26   150  706               50    4
# 3  2022-02-28    5        29          29   150  816               74   21
# 4  2022-03-01    6        29          29   198  846               77   24
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0            100         60      0           2                      0
# 1            130         60      2           2                      0
# 2            130         60      2           2                      0
# 3            291         60      3           2                      5
# 4            305         60      3           2                      7
#
#    special equipment  mobile SRBM system
# 0                0.0                 1.0
# ...

# %%
df[20:25]
# Out:
#           date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
# 20  2022-03-17   22        86         108   444  1435              201   72
# 21  2022-03-18   23        93         112   450  1448              205   72
# 22  2022-03-19   24        95         115   466  1470              213   72
# 23  2022-03-20   25        96         118   476  1487              230   74
# 24  2022-03-21   26        97         121   498  1535              240   80
#
#     military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 20            864         60     11           3                     43
# 21            879         60     12           3                     43
# 22            914         60     17           3                     44
# 23            947         60     21           3                     44
# 24            969         60     24           3                     45
#
#     special equipment  mobile SRBM system
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = [ i for i in range(1,42)]
y = df['APC']
y2 = df['tank']

plt.plot(x,y ,'o-r',label='helicopter')
plt.plot(x,y2,'*:b',label='tank')
plt.plot()
plt.show()
